# %%
# %pylab inline
import random
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### CDF/PDF for density
# * $f(a)$ is a PDF:
# $$Pr(a\leq X \leq b) = \int_a^b f(x) dx$$
# * $F(a)$ is a CDF:
# $$F(a) = Pr(X\leq a) = \int_{-\infty}^a f(x) dx$$
# *
# $$f(a)  = \left. \frac{d}{dx} F(x) \right|_{x=a} $$

# %% [markdown]
# ### CDF for empirical distribution
# We have a sample $x_1,\ldots,x_n$
# $$\hat{F}(a) = \frac{1}{n} |\{i \mbox{ such that } x_i \leq a\}|$$
# * What about the PDF for empirical distribution? We cannot take the derivative...  The closest we have to and empirical pdf is the histogram.

# %% [markdown]
# ### Calculating the probability of a segment
# * The true probability
# $$P(a\leq X \leq b) = \int_a^b f(x) dx = \int_{-\infty}^b f(x)dx - \int_{-\infty}^a f(x)dx = $$
#
# * The empirical probability. We have a sample $x_1,\ldots,x_n$
# $$\hat{P}(a \leq X \leq b) = \frac{1}{n} |\{i \mbox{ such that } a \leq x_i \leq b\} = $$

# %% [markdown]
# ### Empirical CDFs vs. histograms
# * The histogram coverges to the density function
# * The emprirical CDF converges to the true CDF
# * The convergence of the CDF is much faster.

# %%
from scipy.stats import norm
def plot_normal(mu=1,sigma=1, n=20, m=100, plot_pdf_model=True,plot_cdf_model=True,
               plot_pdf_empir=True,plot_cdf_empir=True):
    s = np.random.normal(mu, sigma, n)

    xmin=-4; xmax=6; delta=1/n
    x=arange(xmin,xmax,delta)
    if plot_cdf_model:
        _cdf=norm.cdf(x,loc=mu,scale=sigma)
        plot(x,_cdf)
    if plot_pdf_model:
        _pdf=norm.pdf(x,loc=mu,scale=sigma)
        plot(x,_pdf)
    grid()
    if plot_cdf_empir:
        q=sorted(s)
        P=arange(0,1,1/s.shape[0])
        plot(q,P)
    if plot_pdf_empir:
        plt.hist(s, 30, density=True);
    
    return s,x,

# %%
plot_normal(n=10000)
# Out:
# (array([ 1.39580232,  1.34186618,  2.75797503, ...,  1.2667195 ,
#         -0.73335829,  1.27744453]),
#  array([-4.    , -3.9999, -3.9998, ...,  5.9997,  5.9998,  5.9999]))

# %%
plot_normal(n=200)
# Out:
# (array([ 1.76700072,  1.34049357,  0.99187523,  1.71662774,  0.5911452 ,
#          1.47677192, -0.10325355,  1.10845784,  0.72818481,  1.18925822,
#          0.78942646, -0.21550112,  0.05988004,  2.1295673 ,  1.39112034,
#          2.11935427,  1.44479774,  0.092335  ,  1.5085402 ,  0.50726003,
#          2.51183127,  0.84701349,  0.36164401,  1.93180376,  0.65917932,
#         -0.64356023,  1.62685674,  1.35173263,  1.47992191,  1.2421422 ,
#          0.31798475, -0.10512578, -0.31871556, -0.05979855,  0.20859187,
#         -0.51349905,  0.9233188 ,  0.07882876, -0.27987153, -0.23657454,
#          1.37337517,  2.44539668,  2.07556781, -0.23725426,  1.45883695,
#         -0.27384224,  1.92384387,  1.32124785,  1.35450464,  2.32060275,
#          0.9421833 ,  1.54335661, -0.28366268,  0.6767954 ,  0.39713527,
#          1.85896055, -0.11675975, -0.03470421, -1.26992264,  2.13638915,
#          1.20464906,  0.18977089,  0.07302039,  0.4251721 ,  1.402723  ,
#          4.80000000e+00,  4.85000000e+00,  4.90000000e+00,  4.95000000e+00,
#          5.00000000e+00,  5.05000000e+00,  5.10000000e+00,  5.15000000e+00,
#          5.20000000e+00,  5.25000000e+00,  5.30000000e+00,  5.35000000e+00,
#          5.40000000e+00,  5.45000000e+00,  5.50000000e+00,  5.55000000e+00,
#          5.60000000e+00,  5.65000000e+00,  5.70000000e+00,  5.75000000e+00,
#          5.80000000e+00,  5.85000000e+00,  5.90000000e+00,  5.95000000e+00]))

# %% [markdown]
# ## Sorting data that comes from a distribution
#
# The best sorting time for arbitrary data: $O(n \log n)$ (quicksort)
#
# For data that is sampled from a fixed distribution (Independent Identically Distributed or IID) we can sort in $O(n)$ time!

# %% [markdown]
# ### Easiest case: Uniform distribution.

# %%
n=10000
R=array([random.uniform(0,1) for i in range(n)])

# %%
hist(R,density=True);
grid()

# %% [markdown]
# ### Create a list of lists
# * Size of (outside) list is $n$.
# * Each inside list starts empty.

# %%
m=n #int(n/10)
L=[[] for i in range(m)]

for r in R:
    i=int(r*m) # scale random number from [0,1] to [0,n]
    L[i].append(r) #append number to list at location i

# %%
L[:2]
# Out:
# [[], [0.00012736235033294907]]

# %% [markdown]
# ### Size of fullest bin

# %%
lengths=[len(l) for l in L]
min(lengths),max(lengths)
# Out:
# (0, 6)

# %% [markdown]
# ### sort each short list and concatanate

# %%
_sorted=[]
for l in L:
    _sorted +=sorted(l)

# %%
_sorted[:10]
# Out:
# [0.00012736235033294907,
#  0.00026897434786088414,
#  0.0003041252138814565,
#  0.0003461793104323485,
#  0.0006533281570326732,
#  0.0008120512758655885,
#  0.0010327512303338615,
#  0.0010433753928398293,
#  0.0011622448788152218,
#  0.0011850268497707317]

# %%
resort=sorted(_sorted)   # checking that the order is good.
resort==_sorted
# Out:
# True

# %% [markdown]
# ### What about distributions other than uniform
# We can use the CDF of a distribution to transform it into a uniform distribution.

# %%
from scipy.stats import norm

# %%
plot_normal(n=100,plot_pdf_model=False,plot_pdf_empir=False,plot_cdf_empir=False)
# Out:
# (array([ 1.48834965, -0.10305302,  0.63936677,  0.09034743,  1.15410957,
#          0.36125569,  0.65275006,  0.22498215,  2.46787402,  1.68979236,
#          0.29967692,  1.05952166,  2.3720901 ,  2.81112833, -0.25492909,
#          0.82484052,  1.13928648, -0.32668255,  1.55584767,  0.97392394,
#          0.50217824, -0.23218926,  0.97334186,  0.16450395,  1.87479733,
#          0.48680686, -0.12480167,  1.00249973,  1.92915204,  0.88440453,
#          1.75182018,  1.67294228,  0.82860198,  1.99056399, -0.39718297,
#          0.47480159,  1.11804552,  0.45141859,  1.28246438,  0.69880793,
#          1.2333651 ,  1.06732095, -1.31415166,  1.03979727, -0.12693795,
#          2.37449399,  1.81808984,  0.56433141,  0.18950789,  1.06874825,
#         -0.19597174, -0.43259998,  1.14072092, -0.011172  ,  0.2547957 ,
#          3.30068563,  1.19191322, -0.03209099,  1.73374412,  0.74037394,
#         -0.12127422,  1.76438592, -0.24163166,  1.02470954,  1.08657381,
# * $F(x) = P(X \leq x)$
# *
# * $X$ is a random variable, therefor $F(X)$ is a random variable.
# *
# * What is the distribution of the RV $F(X)$ ?
# * $0 \leq F(X) \leq 1$, Therefor $P(0 \leq F(X) \leq 1) = ? $
#  * What is the probability that $0\leq A \leq F(X) \leq B \leq 1$

# %%
figure(figsize=[15,10])
mu=1; sigma=1; n=10000; m=100
s = np.random.normal(mu, sigma, n)

xmin=-4; xmax=6; delta=1/n
x=arange(xmin,xmax,delta)
cdf=norm.cdf(x,loc=mu,scale=sigma)
plot(x,cdf)
grid()
plt.hist(s, 30, density=True);

# %% [markdown]
# * $F(x)$ is a non-decreasing function from $(-\infty,+\infty)$ to $[0,1]$. Therefor for any $0 \leq A \leq B \leq 1$ there exists $a \leq b$ such that $F(a)=A$,$F(b)=B$.

# %% [markdown]
# * $P( a < X \leq b) = P(A \leq F(X) \leq B)$
# *
# * On the other hand $P( a \leq X \leq b) = F(b)-F(a) = $
# *
# * Therefor, for any $0 \leq A \leq B \leq 1$:
# $ P(A \leq F(X) \leq B) = B-A $
# *
# ** Which implies that the distribution of $F(X)$ is ?

# %%
index=np.array(x.shape[0]*(s-xmin)/(xmax-xmin),dtype=np.int)
scaled=cdf[index]
hist(scaled,density=True);
grid()

# %% [markdown]
# ### We can now use the sorting method for the uniform distribution

# %%
m=100
L=[[] for i in range(m)]

for j in range(s.shape[0]):
    r=s[j]
    _scale=scaled[j]
    i=int(_scale*m)
    L[i].append(r)

# %%
_sorted=[]
for l in L:
    _sorted +=sorted(l)

# %%
_sorted[:10]
# Out:
# [-2.4367423791606937,
#  -2.3015312640056935,
#  -2.3009203778977363,
#  -2.2759528503488866,
#  -2.260879755629866,
#  -2.2482401905994505,
#  -2.2348722179060094,
#  -2.206303750911871,
#  -2.1877838028964502,
#  -2.1563378477754607]

# %%
resort=sorted(_sorted)   # checking that the order is good.
resort==_sorted
# Out:
# True

# %% [markdown]
# ###  Sorting when the distribution is not known
# When the distribution is not know, we can use the empirical CDF

# %%
## Lets generate a complicated distribution
n=20000
s1 = np.random.normal(0, 1, n)
s2 = np.random.normal(5, 2, n)
s3 = np.random.normal(-10, 5, 2*n)
s=concatenate([s1,s2,s3])
s.shape
# Out:
# (80000,)

# %%
hist(s,bins=100);

# %% [markdown]
# ### Calculating the CDF requires sorting
# So calculating the CDF requires sorting and $O(n)$ sorting requires knowing the CDF ...
#
# Are we stuck in an infinite loop?

# %%
def plot_CDF(s):
    x=sorted(s)
    p=arange(0,1,1/s.shape[0])
    plot(x,p,label=str(s.shape[0]))

# %%
plot_CDF(s)
grid()
legend();

# %% [markdown]
# ### Are we stuck?
#
# * **No!** we can approximate the CDF using a sample
# * Estimating the CDF does not require many examples (proof: more advanced probability)

# %%
from numpy.random import choice

# %%
figure(figsize=[15,10])
for m in [50,500,80000]:
    sample=choice(s,m)
    plot_CDF(sample)
grid()
legend()

# %% [markdown]
# ###  in HW5
# We don't need a perfect CDF, we just need the resulting distribution to be approximately uniform over [0,1]
#
# Write a program that takes as input $n$ data points drawn from some distribution, and sorts this data in $O(n)$
